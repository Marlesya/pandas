# %% [markdown]
# #05: Membalik urutan baris dan kolom pada Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  9  2  1  1
# 1  5  6  8  6  4
# 2  2  1  5  9  6
# 3  8  1  5  8  1
# 4  3  1  9  5  4

# %%
df.loc[:, ::-1]
# Out:
#    E  D  C  B  A
# 0  1  1  2  9  6
# 1  4  6  8  6  5
# 2  6  9  5  1  2
# 3  1  8  5  1  8
# 4  4  5  9  1  3

# %%
df.loc[::-1]
# Out:
#    A  B  C  D  E
# 4  3  1  9  5  4
# 3  8  1  5  8  1
# 2  2  1  5  9  6
# 1  5  6  8  6  4
# 0  6  9  2  1  1

# %%
df.loc[::-1].reset_index(drop=True)
# Out:
#    A  B  C  D  E
# 0  3  1  9  5  4
# 1  8  1  5  8  1
# 2  2  1  5  9  6
# 3  5  6  8  6  4
# 4  6  9  2  1  1

# %% [markdown]
# #06: Mengganti nama (label) kolom pada Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), 
                  columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  6  9  4  3  4
# 1  1  3  4  1  3
# 2  5  3  8  7  6
# 3  1  7  1  2  1
# 4  7  3  5  8  8

# %%
df.rename(columns={'C':'Hobi'})
# Out:
#    A  B  Hobi  D  E
# 0  6  9     4  3  4
# 1  1  3     4  1  3
# 2  5  3     8  7  6
# 3  1  7     1  2  1
# 4  7  3     5  8  8

# %%
df.rename(columns={'A':'Nama', 'B':'Alamat', 'D':'Kota'})
# Out:
#    Nama  Alamat  C  Kota  E
# 0     6       9  4     3  4
# 1     1       3  4     1  3
# 2     5       3  8     7  6
# 3     1       7  1     2  1
# 4     7       3  5     8  8

# %% [markdown]
# #07: Menghapus (drop) missing values (NaN)

# %%
import pandas as pd

print(pd.__version__)
# Out:
# 2.3.3

# %%
n_rows = 30
n_cols = 4
cols = ['A', 'B', 'C', 'D']

df = pd.DataFrame(np.random.randn(n_rows, n_cols), columns=cols)

nan_mask = np.random.rand(n_rows, n_cols) < 0.2
df[nan_mask] = np.nan

df = df.reset_index()
df.head()
# Out:
#    index         A         B         C         D
# 0      0       NaN -0.422431 -1.278741 -1.398756
# 1      1  0.998390 -1.767938 -1.750988       NaN
# 2      2  1.248853  0.513649       NaN -0.328894
# 3      3  0.200365 -0.684935 -1.921078  0.242433
# 4      4  1.466274       NaN  1.564435       NaN

# %%
df = df.rename(columns={'index':'Z'})
df.head()
# Out:
#    Z         A         B         C         D
# 0  0       NaN -0.422431 -1.278741 -1.398756
# 1  1  0.998390 -1.767938 -1.750988       NaN
# 2  2  1.248853  0.513649       NaN -0.328894
# 3  3  0.200365 -0.684935 -1.921078  0.242433
# 4  4  1.466274       NaN  1.564435       NaN

# %%
df_backup = df.copy(deep=True)

# %%
df = df.dropna(axis='columns') 
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %%
df = df_backup.copy(deep=True)
df = df.dropna(axis='rows')
df.head()
# Out:
#      Z         A         B         C         D
# 3    3  0.200365 -0.684935 -1.921078  0.242433
# 6    6  0.303700  0.511064 -1.357857  1.366213
# 8    8 -0.075138  2.068417 -0.131087  0.504541
# 11  11  0.021469  1.885235  1.452283 -0.627268
# 16  16  1.005820 -2.354509  0.517959 -0.757074

# %%
df = df_backup.copy(deep=True)
df.isna().mean()
# Out:
# Z    0.000000
# A    0.300000
# B    0.300000
# C    0.200000
# D    0.233333
# dtype: float64

# %%
treshold = len(df) * 0.9
df = df.dropna(thresh=treshold, axis='columns')
df.head()
# Out:
#    Z
# 0  0
# 1  1
# 2  2
# 3  3
# 4  4

# %% [markdown]
# #08: Memeriksa kesamaan antar dua buah kolom (Series) pada Data Frame

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 2.3.3
# 2.3.4

# %%
data = {'A':[15, 15, 18, np.nan, 12], 
        'B':[15, 15, 18, np.nan, 12]}

df = pd.DataFrame(data)
df
# Out:
#       A     B
# 0  15.0  15.0
# 1  15.0  15.0
# 2  18.0  18.0
# 3   NaN   NaN
# 4  12.0  12.0

# %%
df['A']
# Out:
# 0    15.0
# 1    15.0
# 2    18.0
# 3     NaN
# 4    12.0
# Name: A, dtype: float64

# %%
type(df['A'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df['A'] == df['B']
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# dtype: bool

# %%
df['A'].equals(df['B'])
# Out:
# True

# %%
df1 = df.copy(deep=True)

df.equals(df1)
# Out:
# True

# %%
df == df1
# Out:
#        A      B
# 0   True   True
# 1   True   True
# 2   True   True
# 3  False  False
# 4   True   True
